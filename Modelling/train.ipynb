# %% [markdown]
# #Connecto to gg drive

# %%
from google.colab import drive
drive.mount('/content/drive')


import sys
modulename = 'google'
if modulename not in sys.modules:
    print('You have not imported the {} module'.format(modulename))
else:
  print('You have imported the {} module'.format(modulename))
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# You have imported the google module

# %% [markdown]
# #Py 3.8 set up

# %%
# !sudo apt-get install python3.8
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1
# !sudo apt install  python3.8-distutils
# !sudo apt install python3-pip

# Run with python3.8 binary
# !which python3
# Out:
# /usr/bin/python3

# %%
# !pip install -r /content/drive/MyDrive/spelling_correction/requirements.txt
# !pip install torch==1.8.0+cu111 torchvision==0.9.0+cu111 torchaudio==0.8.0 -f https://download.pytorch.org/whl/torch_stable.html
# Verify torch & gpu
# !python3 -m torch.utils.collect_env
# !nvidia-smi

# %% [markdown]
# #Training

# %%
# !/usr/bin/python3 /content/drive/MyDrive/spelling_correction/source/train.py
# device.reset() # for remove allocated mem when error
# Out:
# Generating new dataset...
# 	Saving SRC and TRG files...
# 	Finished saving SRC and TRG files.
# Finished.
# Length of SRC vocab: 29, TRG vocab: 31
# Model is saved at the end of each epoch.
# Training model...
# Epoch 1/100:
# Time: 3.0458879470825195.
# Loss: 4.127507209777832
# F1 Score: 0.07928208261728287
# Save model after 1 epoch(s).
# Generating new dataset for the next epoch...
# 	Saving SRC and TRG files...
# 	Finished saving SRC and TRG files.
# Finished.
#
# Epoch 2/100:
# Time: 2.74713134765625.
# Loss: 3.912203788757324
# F1 Score: 0.07348784804344177
# Save model after 2 epoch(s).
# Generating new dataset for the next epoch...
# 	Saving SRC and TRG files...
# 	Finished saving SRC and TRG files.
# Finished.
#
# Epoch 3/100:
# Time: 2.743312120437622.
# Loss: 3.2484235763549805
# F1 Score: 0.09793668985366821
# Save model after 3 epoch(s).
# Generating new dataset for the next epoch...
# 	Saving SRC and TRG files...
# 	Finished saving SRC and TRG files.
# Finished.
#
# ...
