# %% [markdown]
# #Connecto to gg drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Py 3.8 set up

# %%
# !sudo apt-get install python3.8
# !sudo update-alternatives --install /usr/bin/python3 python3 /usr/bin/python3.8 1
# !sudo apt install  python3.8-distutils
# !sudo apt install python3-pip

# Run with python3.8 binary
# !which python3
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.8 is already the newest version (3.8.18-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3.8-distutils is already the newest version (3.8.18-1+jammy1).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-pip is already the newest version (22.0.2+dfsg-1ubuntu0.3).
# 0 upgraded, 0 newly installed, 0 to remove and 19 not upgraded.
# /usr/bin/python3

# %%
# !pip install -r /content/drive/MyDrive/Modelling/colab_requirements.txt
# !pip install torch==1.8.0+cu111 torchvision==0.9.0+cu111 torchaudio==0.8.0 -f https://download.pytorch.org/whl/torch_stable.html
# !/usr/bin/python3 -m spacy download en_core_web_sm

# Verify torch & gpu
# !python3 -m torch.utils.collect_env
# !nvidia-smi

# %% [markdown]
# #Training

# %%
# import colab in the following files:
#     train.py
#     transformer.py
#     preprocess.py
# when running in colab

# !/usr/bin/python3 -batch_size=7000 -batch_size=50 -threshold=0.94 /content/drive/MyDrive/Modelling/train.py
# device.reset() # for remove allocated mem when error
# Out:
# Generating new dataset...
# 	Saving SOURCE and TARGET files...
# 	Finished saving SOURCE and TARGET files.
# Finished.
# Length of SOURCE vocab: 41, TARGET vocab: 43
# Model is saved at the end of each epoch.
# Training model...
# Epoch 1/50:
#  48% 715/1500 [07:22<08:05,  1.62it/s]
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/Modelling/train.py", line 142, in <module>
#     main()
#   File "/content/drive/MyDrive/Modelling/train.py", line 138, in main
#     train_model(model, option, SOURCE, TARGET)
#   File "/content/drive/MyDrive/Modelling/train.py", line 73, in train_model
#     preds = model(source, target_input, source_mask, target_mask)
#   File "/usr/local/lib/python3.8/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
#   File "/content/drive/MyDrive/Modelling/transformer.py", line 59, in forward
#     encoder_outputs = self.encoder(source, source_mask)
# ...
